# %%
from agents import Agent, Runner

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
agent=Agent(name="Assistant",instructions="You are a helpful assistant",model="gpt-4.1-nano")
result = await Runner.run(agent, input="Write a haiku about recursion in programming.")
print(result.final_output)
# Out:
# c:\Openai_agent_SDK\venv\Lib\site-packages\pydantic\_internal\_typing_extra.py:500: RuntimeWarning: coroutine 'AgentRunner.run' was never awaited
#   return typing._eval_type(  # type: ignore
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# Calls within themselves—
# A endless echo reborn,
# Logic’s infinite.

# %%
import agents.mcp.util
dir(agents.mcp.util)
# Out:
# ['AgentsException',
#  'Any',
#  'Callable',
#  'FunctionSpanData',
#  'FunctionTool',
#  'MCPUtil',
#  'MaybeAwaitable',
#  'ModelBehaviorError',
#  'NotRequired',
#  'Optional',
#  'RunContextWrapper',
#  'TYPE_CHECKING',
#  'Tool',
#  'ToolFilter',
#  'ToolFilterCallable',
#  'ToolFilterContext',
#  'ToolFilterStatic',
#  'TypedDict',
#  'Union',
#  'UserError',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_debug',
#  'create_static_tool_filter',
#  'dataclass',
#  'ensure_strict_json_schema',
#  'functools',
#  'get_current_span',
#  'json',
#  'logger',
#  'mcp_tools_span']

# %%
from agents.mcp.server import MCPServerStdio
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from agents.mcp.server import MCPServerStdio
#
# File c:\Openai_agent_SDK\venv\Lib\site-packages\agents\mcp\server.py:12
#       9 from typing import TYPE_CHECKING, Any, Literal, cast
#      11 from anyio.streams.memory import MemoryObjectReceiveStream, MemoryObjectSendStream
# ---> 12 from mcp import ClientSession, StdioServerParameters, Tool as MCPTool, stdio_client
#      13 from mcp.client.sse import sse_client
#      14 from mcp.client.streamable_http import GetSessionIdCallback, streamablehttp_client
#
# File c:\Openai_agent_SDK\mcp.py:5
#       3 from agents import Agent
#       4 from agents.run_context import RunContextWrapper
# ----> 5 from agents.mcp import MCPServerStdio
#       7 samples_dir="./samples"
#       8 async def main():
#
# ImportError: cannot import name 'MCPServerStdio' from 'agents.mcp' (c:\Openai_agent_SDK\venv\Lib\site-packages\agents\mcp\__init__.py)
